# %% [markdown]
# # Eamon Glackin - Duolingo Director of Marketing Analytics
# ## Take Home Data Analysis Task

# %% [markdown]
# The first cell will contain all the necessary package imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
survey_data_file = './data/survey_data.csv'
app_usage_file = './data/survey_users_app_usage.csv'
df_survey = pd.read_csv(survey_data_file)
df_app = pd.read_csv(app_usage_file, parse_dates=['duolingo_start_date'])

# %%
df_survey.head()
# Out:
#                             user_id      age       annual_income country  \
# 0  35c9fc6e72c911e99681dca9049399ef    18-34   $26,000 - $75,000      JP
# 1  35c9fdde72c911e98630dca9049399ef    18-34   $26,000 - $75,000      JP
# 2  35c9feb072c911e9ab4cdca9049399ef    18-34  $76,000 - $150,000      JP
# 3  35c9ff7072c911e9900ddca9049399ef    18-34  $76,000 - $150,000      JP
# 4  35ca002672c911e99effdca9049399ef  35 - 54  $76,000 - $150,000      JP
#
#          duolingo_platform                               duolingo_subscriber  \
# 0  Android phone or tablet           No, I have never paid for Duolingo Plus
# 1           iPhone or iPad           No, I have never paid for Duolingo Plus
# 2           iPhone or iPad            Yes, I currently pay for Duolingo Plus
# 3           iPhone or iPad  No, but I have previously paid for Duolingo Plus
# 4  Android phone or tablet            Yes, I currently pay for Duolingo Plus
#
#   duolingo_usage   employment_status future_contact  gender  \
# 0          Daily  Employed full-time            Yes    Male
# 1         Weekly  Employed full-time            Yes    Male
# 2          Daily  Employed full-time            Yes    Male
# 3          Daily  Employed full-time            Yes  Female
# 4          Daily  Employed full-time            Yes    Male
#
#                                    other_resources  \
# 0  Stories/novels/children's books,Movies/TV Shows
# 1                                              NaN
# 2                                              NaN
# 3                                       Other apps
# 4                                              NaN
#
#                          primary_language_commitment  \
# 0      I'm very committed to learning this language.
# 1  I'm slightly committed to learning this language.
# 2  I'm moderately committed to learning this lang...
# 3      I'm very committed to learning this language.
# 4      I'm very committed to learning this language.
#
#                              primary_language_review  \
# 0  I am using Duolingo to review a language I've ...
# 1  I am using Duolingo to review a language I've ...
# 2  I am using Duolingo to review a language I've ...
# 3  I am using Duolingo to learn this language for...
# 4  I am using Duolingo to learn this language for...
#
#                          primary_language_motivation  \
# 0                      I like to learn new languages
# 1  I need to be able to speak the local language ...
# 2     I want to connect with my heritage or identity
# 3                          I am preparing for a trip
# 4     I want to connect with my heritage or identity
#
#                 primary_language_motivation_followup  \
# 0  I want to learn as many languages as I can,Oth...
# 1                   I am an immigrant,I am a refugee
# 2                                                NaN
# 3  I want to learn some basics in the local langu...
# 4                                                NaN
#
#   primary_language_proficiency                  student  survey_complete  \
# 0                     Advanced  Not currently a student                1
# 1                 Intermediate  Not currently a student                1
# 2                     Beginner  Not currently a student                1
# 3                 Intermediate  Not currently a student                1
# 4                 Intermediate  Not currently a student                1
#
#    time_spent_seconds
# 0                 193
# 1                 139
# 2                 119
# 3                 229
# 4                 157

# %%
df_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6187 entries, 0 to 6186
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   user_id                               6187 non-null   object
#  1   age                                   5838 non-null   object
#  2   annual_income                         5182 non-null   object
#  3   country                               6187 non-null   object
#  4   duolingo_platform                     5911 non-null   object
#  5   duolingo_subscriber                   5901 non-null   object
#  6   duolingo_usage                        5911 non-null   object
#  7   employment_status                     5730 non-null   object
#  8   future_contact                        5446 non-null   object
#  9   gender                                5838 non-null   object
#  10  other_resources                       4474 non-null   object
#  11  primary_language_commitment           6022 non-null   object
#  12  primary_language_review               6014 non-null   object
#  13  primary_language_motivation           5948 non-null   object
#  14  primary_language_motivation_followup  3715 non-null   object
#  15  primary_language_proficiency          6027 non-null   object
#  16  student                               5523 non-null   object
#  17  survey_complete                       6187 non-null   int64
#  18  time_spent_seconds                    6187 non-null   int64
# dtypes: int64(2), object(17)
# memory usage: 918.5+ KB

# %%
print(len(df_survey['user_id']))
print(len(df_survey['user_id'].unique()))
# Out:
# 6187
# 6150

# %%
df_survey[df_survey.duplicated(subset='user_id',keep=False)].sort_values(by='user_id')
# Out:
#                                user_id      age      annual_income country  \
# 30    35ca11b872c911e984abdca9049399ef    18-34  $11,000 - $25,000      JP
# 447   35ca11b872c911e984abdca9049399ef    18-34       $0 - $10,000      JP
# 6064  35ca57a372c911e98c79dca9049399ef  35 - 54                NaN      DE
# 6030  35ca57a372c911e98c79dca9049399ef    18-34  $11,000 - $25,000      JP
# 6035  35ca6ffa72c911e993bcdca9049399ef    18-34  $26,000 - $75,000      JP
# ...                                ...      ...                ...     ...
# 6036  35d6a26672c911e99139dca9049399ef      NaN                NaN      US
# 6092  35d72ec072c911e9888ddca9049399ef    18-34       $0 - $10,000      US
# 6057  35d72ec072c911e9888ddca9049399ef    18-34  $11,000 - $25,000      BR
# 6082  35d73b1972c911e9b6ffdca9049399ef      NaN                NaN      DE
# 6047  35d73b1972c911e9b6ffdca9049399ef      NaN                NaN      DE
#
#             duolingo_platform                      duolingo_subscriber  \
# 30             iPhone or iPad  No, I have never paid for Duolingo Plus
# 447            iPhone or iPad  No, I have never paid for Duolingo Plus
# 6064  Android phone or tablet  No, I have never paid for Duolingo Plus
# 6030           iPhone or iPad  No, I have never paid for Duolingo Plus
# 6035           iPhone or iPad   Yes, I currently pay for Duolingo Plus
# ...                       ...                                      ...
# 6036                      NaN                                      NaN
# 6092           iPhone or iPad  No, I have never paid for Duolingo Plus
# 6057           iPhone or iPad  No, I have never paid for Duolingo Plus
# 6082                      NaN                                      NaN
# 6047                      NaN                                      NaN
#
#      duolingo_usage   employment_status future_contact  gender  \
# 30            Daily  Employed part-time            Yes  Female
# 447           Daily  Employed part-time            Yes  Female
# 6064          Daily  Employed full-time            Yes    Male
# 6030          Daily          Unemployed            Yes    Male
# 6035          Daily  Employed full-time            Yes  Female
# ...             ...                 ...            ...     ...
# 6036            NaN                 NaN            NaN     NaN
# 6092         Weekly  Employed part-time            Yes  Female
# 6057         Weekly  Employed part-time            Yes  Female
# 6082            NaN                 NaN            NaN     NaN
# 6047            NaN                 NaN            NaN     NaN
#
#                                         other_resources  \
# 30    Speak with others (language events, conversati...
# 447                               Online language class
# 6064                                         Other apps
# 6030  Textbooks,Stories/novels/children's books,Movi...
# 6035                                    Movies/TV Shows
# ...                                                 ...
# 6036                                                NaN
# 6092  In-person language class,Online language class...
# 6057                                                NaN
# 6082                                                NaN
# 6047                                                NaN
#
#                             primary_language_commitment  \
# 30    I'm extremely committed to learning this langu...
# 447   I'm extremely committed to learning this langu...
# 6064      I'm very committed to learning this language.
# 6030  I'm extremely committed to learning this langu...
# 6035  I'm extremely committed to learning this langu...
# ...                                                 ...
# 6036                                                NaN
# 6092      I'm very committed to learning this language.
# 6057      I'm very committed to learning this language.
# 6082                                                NaN
# 6047                                                NaN
#
#                                 primary_language_review  \
# 30    I am using Duolingo to learn this language for...
# 447   I am using Duolingo to learn this language for...
# 6064  I am using Duolingo to learn this language for...
# 6030  I am using Duolingo to learn this language for...
# 6035  I am using Duolingo to review a language I've ...
# ...                                                 ...
# 6036                                                NaN
# 6092  I am using Duolingo to review a language I've ...
# 6057  I am using Duolingo to learn this language for...
# 6082                                                NaN
# 6047                                                NaN
#
#                             primary_language_motivation  \
# 30                           I want to challenge myself
# 447                          I want to challenge myself
# 6064  I need to be able to speak the local language ...
# 6030      I want my family to learn a language together
# 6035                          I am preparing for a trip
# ...                                                 ...
# 6036                                                NaN
# 6092           I need to learn this language for school
# 6057            I want to use my time more productively
# 6082                                                NaN
# 6047                                                NaN
#
#                    primary_language_motivation_followup  \
# 30                                                  NaN
# 447                                                 NaN
# 6064                               I am studying abroad
# 6030                                                NaN
# 6035  I want to communicate with locals in a meaning...
# ...                                                 ...
# 6036                                                NaN
# 6092  I am required to use Duolingo in a class I am ...
# 6057  I want to spend less time on social media,Othe...
# 6082                                                NaN
# 6047                                                NaN
#
#      primary_language_proficiency                  student  survey_complete  \
# 30                       Beginner        Full-time student                1
# 447                      Beginner        Part-time student                1
# 6064                     Beginner  Not currently a student                1
# 6030                 Intermediate  Not currently a student                1
# 6035                 Intermediate  Not currently a student                1
# ...                           ...                      ...              ...
# 6036                          NaN                      NaN                0
# 6092                     Beginner        Full-time student                1
# 6057                 Intermediate  Not currently a student                1
# 6082                          NaN                      NaN                0
# 6047                          NaN                      NaN                0
#
#       time_spent_seconds
# 30                   169
# 447                  346
# 6064                 243
# 6030                 311
# 6035                 150
# ...                  ...
# 6036                  13
# 6092                 497
# 6057                 328
# 6082                  24
# 6047                  36
#
# [74 rows x 19 columns]

# %%
df_app.head()
# Out:
#                             user_id duolingo_start_date  daily_goal  \
# 0  35cb7e8f72c911e9888edca9049399ef       6/20/18 21:14         NaN
# 1  35ca34fd72c911e99ed6dca9049399ef         8/8/17 5:01         NaN
# 2  35d1a54a72c911e98e25dca9049399ef      10/15/14 17:55         1.0
# 3  35d4beb072c911e9aa92dca9049399ef        10/5/18 9:28         NaN
# 4  35ccf4bd72c911e9be2edca9049399ef        9/17/15 3:16         NaN
#
#    highest_course_progress took_placement_test  purchased_subscription  \
# 0                     46.0                True                   False
# 1                     50.0                True                   False
# 2                     71.0               False                   False
# 3                      2.0               False                   False
# 4                     34.0               False                   False
#
#    highest_crown_count  n_active_days  n_lessons_started  n_lessons_completed  \
# 0                277.0             88              741.0                668.0
# 1                 62.0             16               57.0                 57.0
# 2                202.0             29              315.0                295.0
# 3                  2.0              3                6.0                  5.0
# 4                216.0             57              338.0                297.0
#
#    longest_streak  n_days_on_platform
# 0             135                 137
# 1               6                 453
# 2              55                1481
# 3               1                  30
# 4              56                1144

# %%
df_app.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6149 entries, 0 to 6148
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  6149 non-null   object
#  1   duolingo_start_date      6149 non-null   object
#  2   daily_goal               2687 non-null   float64
#  3   highest_course_progress  6135 non-null   float64
#  4   took_placement_test      6135 non-null   object
#  5   purchased_subscription   6149 non-null   bool
#  6   highest_crown_count      5857 non-null   float64
#  7   n_active_days            6149 non-null   int64
#  8   n_lessons_started        5993 non-null   float64
#  9   n_lessons_completed      5993 non-null   float64
#  10  longest_streak           6149 non-null   int64
#  11  n_days_on_platform       6149 non-null   int64
# dtypes: bool(1), float64(5), int64(3), object(3)
# memory usage: 534.6+ KB
